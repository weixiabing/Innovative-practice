# %%
import numpy as np
import h5py
import os
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import io
import imageio
from IPython.display import Image, display
from ipywidgets import widgets, Layout, HBox

# %%
#读取数据
f = h5py.File('/content/drive/Shareddrives/gsd/trainX1.h5', 'r')

trainX = f['trainX']

f1 = h5py.File('/content/drive/Shareddrives/gsd/trainY1.h5', 'r')
trainY = f1['trainY']
trainX=np.array(trainX)
trainY=np.array(trainY)


print(trainX.shape)
print(trainY.shape)
# Out:
# (1165, 24, 100, 100, 1)
# (1165, 100, 100, 1)

# %%
# 构造没有确定帧大小的输入层。
inp = layers.Input(shape=(None, *trainX.shape[2:]))

# 使用批量归一化构建 3 个“ConvLSTM2D”层，
# 其次是时空输出的“Conv3D”层。
x = layers.ConvLSTM2D(
    filters=64,
    kernel_size=(5, 5),
    padding="same",
    return_sequences=True,
    activation="relu",
)(inp)
x = layers.BatchNormalization()(x)
x = layers.ConvLSTM2D(
    filters=64,
    kernel_size=(3, 3),
    padding="same",
    return_sequences=True,
    activation="relu",
)(x)
x = layers.BatchNormalization()(x)
x = layers.ConvLSTM2D(
    filters=64,
    kernel_size=(1, 1),
    padding="same",
    return_sequences=False,
    activation="relu",
)(x)
x = layers.Conv2D(
    filters=1, kernel_size=(3, 3), activation="sigmoid", padding="same"
)(x)

# 构建完整的模型并编译它。
model = keras.models.Model(inp, x)
model.summary()
model.compile(
    loss=keras.losses.binary_crossentropy, optimizer=keras.optimizers.Adam(),
)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, None, 100, 100,   0
#                              1)]
#
#  conv_lstm2d (ConvLSTM2D)    (None, None, 100, 100, 6  416256
#                              4)
#
#  batch_normalization (BatchN  (None, None, 100, 100, 6  256
#  ormalization)               4)
#
#  conv_lstm2d_1 (ConvLSTM2D)  (None, None, 100, 100, 6  295168
#                              4)
#
#  batch_normalization_1 (Batc  (None, None, 100, 100, 6  256
#  hNormalization)             4)
#
#  conv_lstm2d_2 (ConvLSTM2D)  (None, 100, 100, 64)      33024
#
#  conv2d (Conv2D)             (None, 100, 100, 1)       577
#
# ...
# Total params: 745,537
# Trainable params: 745,281
# Non-trainable params: 256
# _________________________________________________________________

# %%
from tensorflow.python import test
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5)

# Define modifiable training hyperparameters.
epochs = 20
batch_size = 5

# Fit the model to the training data.
model.fit(
    trainX,
    trainY,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[early_stopping, reduce_lr],
    
)
model.save(os.path.join("/content/drive/Shareddrives/gsd/","Test_call" + ".h5"))
# Out:
# Epoch 1/20
# 233/233 [==============================] - ETA: 0s - loss: 0.0587
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 233/233 [==============================] - 309s 1s/step - loss: 0.0587 - lr: 0.0010
# Epoch 2/20
# 233/233 [==============================] - ETA: 0s - loss: 0.0437
# WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_loss` which is not available. Available metrics are: loss,lr
# 233/233 [==============================] - 292s 1s/step - loss: 0.0437 - lr: 0.0010
# Epoch 3/20
# 233/233 [==============================] - ETA: 0s - loss: 0.0436
# ...
