# %%
from keras.models import Sequential,load_model
import h5py
import matplotlib.pyplot as plt
import numpy as np
import os
import cupy as cp

# %%
#选择要测试kpi sms=0 call=1 internet=2
kpi=0
if kpi==0:
    kpi_name='sms'
elif kpi==1:
    kpi_name='call'
else:
    kpi_name='internet'

# %%
f = h5py.File("D:\downloads\\testX0.7.h5", 'r')

testX = f['testX']
testX = testX[:,:,:,:,kpi]
f1 = h5py.File("D:\downloads\\testY0.7.h5", 'r')
testY = f1['testY']
testY = testY[:,:,:,kpi]
testX=cp.array(testX)
testY=cp.array(testY)
testX=cp.reshape(testX,(testX.shape[0], testX.shape[1], testX.shape[2],testX.shape[3],1))
testY=cp.reshape(testY,(testY.shape[0], testY.shape[1], testY.shape[2],1))


print(testX.shape)
print(testY.shape)
# Out:
# (422, 24, 100, 100, 1)
# (422, 100, 100, 1)

# %%
model = load_model(os.path.join("D:\downloads",f"Test400_{kpi_name}0.7" + ".h5"))
testPredict = model.predict(testX.get())
print(testPredict.shape)
# Out:
# Canceled future for execute_request message before replies were done
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
f2 = h5py.File(f'/content/drive/Shareddrives/gsd/dataset_convlstm/testpred400_{kpi_name}0.7.h5', 'w')
f2.create_dataset('data', data=testPredict)
f2.close()
