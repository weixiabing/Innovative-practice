# %%
import dask.dataframe as dd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential,load_model
import cupy as cp
from keras.layers import LSTM
from  tensorflow.keras.layers import LSTM,Dense,Activation,Dropout
from  tensorflow.keras.callbacks import History,Callback,EarlyStopping
import os

data=dd.read_csv('D:\library\Github\Innovative-practice\library\csv\第三学期\data_n.csv')
data_cp=cp.array(data)

# %%
# 数据归一化
data_cp=data_cp[:1488,:]
scaler=MinMaxScaler(feature_range=(0,1))
data_normalize=scaler.fit_transform(data_cp.get())

# %%
train_size = int(len(data_normalize) * 0.8)
trainlist = data_normalize[:train_size]
testlist = data_normalize[train_size:]

# %%
def create_dataset(dataset, look_back):
#这里的look_back与timestep相同
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back),[0,1,2,4]]
        dataX.append(a)
        dataY.append(dataset[i + look_back,3])
    return cp.array(dataX),cp.array(dataY)
#训练数据太少 look_back并不能过大
look_back = 3
trainX,trainY  = create_dataset(trainlist,look_back)
testX,testY = create_dataset(testlist,look_back)
trainX = cp.reshape(trainX, (trainX.shape[0], trainX.shape[1], 4))
testX = cp.reshape(testX, (testX.shape[0], testX.shape[1] ,4 ))
trainY = cp.reshape(trainY, (trainY.shape[0], 1))
testY = cp.reshape(testY, (testY.shape[0], 1))

# %%
print(trainX.shape)
print(trainY.shape)
# Out:
# (1186, 3, 4)
# (1186, 1)

# %%
model = Sequential()
model.add(LSTM(80,input_shape=(trainX.shape[1],trainX.shape[2]),
                   return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(80,return_sequences=False))
model.add(Dropout(0.2))

model.add(Dense(trainY.shape[1]))
model.add(Activation("relu"))

model.summary()

cbs = [History(), EarlyStopping(monitor='val_loss',
                                patience=10,
                                min_delta=0.00001,
                                verbose=0)]
model.compile(loss='mse',optimizer='adam')
model.fit(trainX.get(),
        trainY.get(),
        batch_size=64,
        epochs=200,
        validation_split=0.2,
        callbacks=cbs,
        verbose=True)
model.save(os.path.join("DATA","Test_lite" + ".h5"))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 3, 80)             27200
#
#  dropout (Dropout)           (None, 3, 80)             0
#
#  lstm_1 (LSTM)               (None, 80)                51520
#
#  dropout_1 (Dropout)         (None, 80)                0
#
#  dense (Dense)               (None, 1)                 81
#
#  activation (Activation)     (None, 1)                 0
#
# =================================================================
# Total params: 78,801
# Trainable params: 78,801
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 15/15 [==============================] - 4s 43ms/step - loss: 0.0924 - val_loss: 0.0787
# Epoch 2/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0595 - val_loss: 0.0674
# Epoch 3/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0555 - val_loss: 0.0650
# Epoch 4/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0530 - val_loss: 0.0628
# Epoch 5/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0499 - val_loss: 0.0596
# Epoch 6/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0460 - val_loss: 0.0540
# Epoch 7/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0400 - val_loss: 0.0464
# Epoch 8/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0341 - val_loss: 0.0390
# Epoch 9/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0312 - val_loss: 0.0369
# Epoch 10/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0309 - val_loss: 0.0359
# Epoch 11/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0297 - val_loss: 0.0379
# Epoch 12/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0289 - val_loss: 0.0355
# Epoch 13/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0288 - val_loss: 0.0338
# Epoch 14/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0272 - val_loss: 0.0331
# Epoch 15/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0277 - val_loss: 0.0335
# Epoch 16/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0260 - val_loss: 0.0299
# Epoch 17/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0261 - val_loss: 0.0294
# Epoch 18/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0252 - val_loss: 0.0299
# Epoch 19/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0243 - val_loss: 0.0263
# Epoch 20/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0217 - val_loss: 0.0262
# Epoch 21/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0216 - val_loss: 0.0255
# Epoch 22/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0203 - val_loss: 0.0225
# Epoch 23/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0202 - val_loss: 0.0213
# Epoch 24/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0200 - val_loss: 0.0215
# Epoch 25/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0191 - val_loss: 0.0210
# Epoch 26/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0185 - val_loss: 0.0188
# Epoch 27/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0187 - val_loss: 0.0221
# Epoch 28/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0171 - val_loss: 0.0223
# Epoch 29/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0171 - val_loss: 0.0233
# Epoch 30/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0167 - val_loss: 0.0179
# Epoch 31/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0156 - val_loss: 0.0176
# Epoch 32/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0161 - val_loss: 0.0178
# Epoch 33/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0158 - val_loss: 0.0179
# Epoch 34/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0156 - val_loss: 0.0193
# Epoch 35/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0156 - val_loss: 0.0187
# Epoch 36/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0161 - val_loss: 0.0176
# Epoch 37/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0148 - val_loss: 0.0176
# Epoch 38/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0155 - val_loss: 0.0179
# Epoch 39/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0153 - val_loss: 0.0178
# Epoch 40/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0149 - val_loss: 0.0177
# Epoch 41/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0150 - val_loss: 0.0209
# Epoch 42/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0150 - val_loss: 0.0193
# Epoch 43/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0149 - val_loss: 0.0178
# Epoch 44/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0149 - val_loss: 0.0180
# Epoch 45/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0141 - val_loss: 0.0181
# Epoch 46/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0148 - val_loss: 0.0181
# Epoch 47/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0144 - val_loss: 0.0175
# Epoch 48/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0143 - val_loss: 0.0171
# Epoch 49/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0147 - val_loss: 0.0193
# Epoch 50/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0154 - val_loss: 0.0180
# Epoch 51/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0146 - val_loss: 0.0184
# Epoch 52/200
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0145 - val_loss: 0.0177
# Epoch 53/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0147 - val_loss: 0.0175
# Epoch 54/200
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0140 - val_loss: 0.0186
# Epoch 55/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0144 - val_loss: 0.0175
# Epoch 56/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0150 - val_loss: 0.0178
# Epoch 57/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0147 - val_loss: 0.0182
# Epoch 58/200
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0138 - val_loss: 0.0174

# %%
model = load_model(os.path.join("DATA","Test_lite" + ".h5"))
trainPredict = model.predict(trainX.get())
testPredict = model.predict(testX.get())
# Out:
# 38/38 [==============================] - 1s 3ms/step
# 10/10 [==============================] - 0s 3ms/step

# %%
print(trainPredict.shape)
print(testPredict.shape)
# Out:
# (1186, 1)
# (294, 1)

# %%
scaler= MinMaxScaler(feature_range=(0, 1)).fit(trainPredict)
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform(trainY.get())
scaler= MinMaxScaler(feature_range=(0, 1)).fit(testPredict)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY.get())

# %%
import matplotlib.pyplot as plt
plt.figure( figsize=(300,10) )
plt.plot(trainY)
plt.plot(trainPredict[1:])
plt.show()

plt.figure( figsize=(100,10) )
plt.plot(testY)
plt.plot(testPredict[1:])
plt.show()

# %%
from  sklearn import  metrics
import numpy as np

def GetRMSE(y_hat,y_test):
    sum = np.sqrt(metrics.mean_squared_error(y_test, y_hat))
    return  sum

def GetMAE(y_hat,y_test):
    sum = metrics.mean_absolute_error(y_test, y_hat)
    return  sum

def GetMAPE(y_hat,y_test):
    sum = np.mean(np.abs((y_hat - y_test) / y_test)) * 100
    return sum

def GetMAPE_Order(y_hat,y_test):
    #删除test_y 为0元素
    zero_index = np.where(y_test == 0)
    y_hat = np.delete(y_hat,zero_index[0])
    y_test = np.delete(y_test,zero_index[0])
    sum = np.mean(np.abs((y_hat - y_test) / y_test)) * 100
    return sum
#计算R2
def GetR2(y_hat,y_test):
    sum = metrics.r2_score(y_test, y_hat)
    return sum


print("RMSE为", GetRMSE(testY, testPredict[:]))
print("MAE为", GetMAE(testY, testPredict[:]))
print("MAPE为", GetMAPE_Order(testY, testPredict[:]))
print("R2为", GetR2(testY, testPredict[:]))
# Out:
# RMSE为 0.2507163928336
# MAE为 0.18499821492255583
# MAPE为 49.321310273715
# R2为 0.4860919280128859
