# %% [markdown]
# 学习日记

# %%
from matplotlib import pyplot as plt
#fig=plt.figure(figsize=(20,8),dpi=80)
x=range(2,26,2)
#数据在x轴位置，是一个可迭代对象
y=[15,13,14.5,17,20,25,26,26,24,22,18,15]
#y轴位置
plt.plot(x,y)
plt.xticks(range(2,26,2))
plt.show()
#plt.savefig('sig_size.svg')

# %% [markdown]
# ![](https://cdn.jsdelivr.net/gh/weixiabing/Innovative-practice/library/pic/note/1.png)

# %%
from matplotlib import pyplot as plt
import random
#fig=plt.figure(figsize=(20,8),dpi=80)
x=range(0,120)
#数据在x轴位置，是一个可迭代对象
y=[random.randint(20,35) for i in range(120)]
#y轴位置
plt.plot(x,y)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7221/3309202514.py in <module>
# ----> 1 coding=utf-8
#       2 from matplotlib import pyplot as plt
#       3 import random
#       4 #fig=plt.figure(figsize=(20,8),dpi=80)
#       5 x=range(0,120)
#
# NameError: name 'utf' is not defined

# %%
from matplotlib import pyplot as plt
import random
#fig=plt.figure(figsize=(20,8),dpi=80)
x=range(0,120)
#数据在x轴位置，是一个可迭代对象
y=[random.randint(20,35) for i in range(120)]
#y轴位置
fig=plt.figure(figsize=(20,8),dpi=80)
_x=list(x)
_xtick_labels=["10点{}分".format(i) for i in range(60)]
_xtick_labels+=["11点{}分".format(i) for i in range(60)]
plt.xticks(_x[::3],_xtick_labels[::3],rotation=90)
plt.plot(x,y)

plt.show()

# %%
matplotlib.rc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7221/759106918.py in <module>
# ----> 1 matplotlib.rc
#
# NameError: name 'matplotlib' is not defined
