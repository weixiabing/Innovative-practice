# %%
from keras.models import Sequential,load_model
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#读取npy testX和testY
testX = np.load('/content/drive/MyDrive/Colab Notebooks/机器学习/365/testX.npy')
testY = np.load('/content/drive/MyDrive/Colab Notebooks/机器学习/365/testY.npy')
print(testX.shape)
print(testY.shape)
# Out:
# (1311, 3, 71, 73, 1)
# (1311, 71, 73, 1)

# %%
model = load_model('/content/drive/MyDrive/Colab Notebooks/机器学习/365/model.h5')
testPredict = model.predict(testX)
print(testPredict.shape)
# Out:
# 41/41 [==============================] - 11s 81ms/step
# (1311, 71, 73, 1)

# %%
#保存
np.save('/content/drive/MyDrive/Colab Notebooks/机器学习/365/testPredict.npy',testPredict)
