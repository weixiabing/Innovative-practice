# %%
#导入../data/testPredict.npy
#导入../data/testY.npy
import numpy as np
import matplotlib.pyplot as plt
import h5py
testPredict = np.load('./data/testPredict.npy')
testY = np.load('./data/testY.npy')
f = h5py.File('./data/datapred_lstm.h5', 'r')
datapred_lstm = f['testPredict']
datapred_lstm  = np.array(datapred_lstm)
f.close()
print(datapred_lstm.shape)
print(testPredict.shape)
print(testY.shape)
data_min = 0.0
data_max = 4435
testPredict = testPredict * (data_max - data_min) + data_min
testY= testY * (data_max - data_min) + data_min
# Out:
# (169200, 1)
# (444, 100, 100, 1)
# (444, 100, 100, 1)

# %%
print(datapred_lstm.shape)
print(testPredict.shape)
print(testY.shape)
# Out:
# (169200, 1)
# (444, 100, 100, 1)
# (444, 100, 100, 1)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import ConnectionPatch
#plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.size'] = 40
plt.rcParams['axes.linewidth'] = 5
# 可视化绘制
fig, ax = plt.subplots(figsize=(40,10),dpi=200)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.set_xlabel('Time(hour)', fontsize=60,labelpad=5)
ax.set_ylabel('# of events', fontsize=60,labelpad=5)
ax.plot(testY[:,50,50,0],'black',label='Ground Truth',linewidth=7)
ax.plot(testPredict[:,50,50,0],'g',label='Convlstm',linewidth=7)
ax.plot(datapred_lstm[(100*423):(100+1)*423],'r-',label='lstm',linewidth=5)
ax.legend(fontsize=30,loc='upper left',frameon=False)
#横线网格
ax.grid(axis='y',linestyle='--',linewidth=2)
